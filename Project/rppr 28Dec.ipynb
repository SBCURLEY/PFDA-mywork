# %% [markdown]
# <div align="center">
#
# # Programming for Data Analytics Project
# ## Residential Property Price Register Analysis
# ***
#
# </div>

# %% [markdown]
# <p align="center">
#     <img width="959" height="539" src="./images/housing_predictions.webp" alt="Sublime's custom image"/
#     >
#     </p>

# %% [markdown]
# ###### [Image from Forbes.com](https://www.forbes.com/advisor/mortgages/real-estate/housing-market-predictions/)

# %% [markdown]
# ### Table of Contents
#
#
# 1. About the Project
#
# 2. Import Libraries
#
# 3. About the Data
#
# 4. Data Exploration
#
#     4.1  Check for the DataFrame
#
#     4.2  Check for the DataFrame dimensionality with pandas .info() method
#
#     4.3  Generate descriptive statistics with pandas .describe method
#
#     4.4  Check for missing values
#
# 5. Data Analysis
#
#     5.1  Analysis of Property Prices in Ireland (2010-2024)
#
#      - 5.1.1    Average property prices by county
#
#      - 5.1.2    Number of property sales by county
#
#      - 5.1.3    Average property prices by year
#
#      - 5.1.4    Average property prices by month
#
#      - 5.1.5    Number of occurrences of each property type
#
#      - 5.1.6    Average property prices by property type (2010-2024)
#
#      - 5.1.7    Full Market price comparison
#
#     5.2 Analysis of Property Prices in Mayo (2010-2024)
#
#      - 5.2.1    Data Preparation for Analysis
#
#      - 5.2.2    Average Mayo Property Price by Year
#
#      - 5.2.3    Average Mayo Property Price by Month
#
#      - 5.2.4    Average Mayo Property Price by month in 2024
#
#      - 5.2.5    Number of property sales in Mayo in 2024
#
#      - 5.2.6    Number of occurrences of each property type in Mayo
#
#      - 5.2.7    Average property price by property type in Mayo in 2024
#
#      - 5.2.8    Full Market price comparison in Mayo
#
#     5.3 Analysis of Property Prices in Castlebar (2024)
#
# 6.  Project References

# %% [markdown]
# ### 1. About the Project
# ***
#
# The project analyses the Residential Property Price Index (RPPI). The RPPI is an important economic indicator that tracks changes in the prices of residential properties across Ireland. The data is collected by the Central Statistics Office (CSO) and provides insights into the trends in the housing market, showing whether property prices are rising or falling over time. This makes the RPPI a valuable tool for homebuyers, sellers, policymakers, and economists to understand and analyse the real estate market. I began my analysis on the national dataset, and then Co. Mayo followed by Castlebar for further analysis.

# %% [markdown]
# ### 2. Import the Libraries
# ***
#
# I imported the following libraries to plot the dataset.
#
# - `matplotlib.pyplot`: Essential for creating static, animated, and interactive visualizations in Python. It is closely integrated with NumPy and provides a MATLAB-like interface for creating plots and visualizations.
# - `numpy`: It contains functionality for multidimensional arrays, high-level mathematical functions such as linear algebra operations.
# - `pandas`: Fundamental data analysis and manipulation library built on top of the Python programming language. It offers data structures and operations for manipulating numerical tables and time series.
# - `seaborn`: Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# - `datetime`: The datetime is a built-in module that provides classes for manipulating dates and times
# - `re`: The re module provides a set of functions to work with regular expressions, used for searching, matching, and manipulating strings.
# - `matplotlib.dates`: Matplotlib provides sophisticated date plotting capabilities, standing on the shoulders of python datetime and the add-on module dateutil.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
import re
import matplotlib.dates as mdates

# %% [markdown]
# ### 3. About the Data
# ***
# The Residential Property Price Register (RPPI) is produced by the Property Services Regulatory Authority (PSRA) pursuant to section 86 of the Property Services (Regulation) Act 2011. It includes Date of Sale, Price and Address of all residential properties purchased in Ireland since the 1st January 2010.The RPPI is compiled from a variety of data sources. The principal data source is stamp duty returns made to the Revenue Commissioners. All transfers of ownership of residential properties in the State must be referred to the Revenue Commissioners for stamp duty assessment under the Stamp Duties Consolidation Act (SDCA) 1999. The data collected includes the address of the property and the sales price. These datasets are matched by the CSO to Building Energy Rating (BER) data, compiled by the Sustainable Energy Authority of Ireland (SEAI). Under Statutory Instrument (S.I.) No. 243 of 2012, all residential property for sale must disclose their BER assessment (with some very minor exceptions). The BER data includes the property address, the total floor area (m2) and the dwelling type (apartment, detached house, semi-detached house, etc.). The BER data are matched to the stamp duty data using an address matching algorithm (or Eircodes, where available on both datasets). [[1]](https://www.cso.ie/en/releasesandpublications/ep/p-rppi/residentialpropertypriceindexjuly2024/backgroundnotes/)
#
# I loaded the dataset from the Residential Property Price Register website [[2]](https://www.propertypriceregister.ie/)
#
# Column 8 contains  a mixed data types. When pandas detected the mixed types, it raised a DtypeWarning because it has to infer the type dynamically, which can lead to performance issues. I included `low_memory=False` to the read command. This option tells pandas to process the file in chunks, which can help avoid the warning when dealing with large files, This doesn't resolve the mixed types but suppresses the warning. [[3]](https://www.geeksforgeeks.org/pandas-read_csv-low_memory-and-dtype-options/) [[4]](https://stackoverflow.com/questions/25488675/mixed-types-when-reading-csv-files-causes-fixes-and-consequences)
#
# ###### [1] [Central Statistics Office: Residential Property Price Index July 2024](https://www.cso.ie/en/releasesandpublications/ep/p-rppi/residentialpropertypriceindexjuly2024/backgroundnotes/)
# ###### [2] [Property Services Regulatory Authority: Residential Property Price Register](https://www.propertypriceregister.ie/)
#
# ###### [3] [GeeksforGeeks: Pandas read_csv: low_memory and dtype options](https://www.geeksforgeeks.org/pandas-read_csv-low_memory-and-dtype-options/)
#
# ###### [4] [Stack Overflow - Mixed types when reading csv files. Causes, fixes and consequences](https://stackoverflow.com/questions/25488675/mixed-types-when-reading-csv-files-causes-fixes-and-consequences)

# %%
df=pd.read_csv("./data/ppr_all.csv", low_memory=False)

# %% [markdown]
# ### 4. Data Exploration
# ***

# %% [markdown]
# #### 4.1 Check the dataframe using df.head

# %% [markdown]
# Lets have an initial glance at the data

# %%
df.head(5)
# Out:
#   Date of Sale (dd/mm/yyyy)                                         Address  \
# 0                01/01/2010          5 Braemor Drive, Churchtown, Co.Dublin
# 1                03/01/2010  134 Ashewood Walk, Summerhill Lane, Portlaoise
# 2                04/01/2010             1 Meadow Avenue, Dundrum, Dublin 14
# 3                04/01/2010                         1 The Haven, Mornington
# 4                04/01/2010                   11 Melville Heights, Kilkenny
#
#      County Eircode  Price in Euro Not Full Market Price VAT Exclusive  \
# 0    Dublin     NaN       343000.0                    No            No
# 1     Laois     NaN       185000.0                    No           Yes
# 2    Dublin     NaN       438500.0                    No            No
# 3     Meath     NaN       400000.0                    No            No
# 4  Kilkenny     NaN       160000.0                    No            No
#
#                  Description of Property  \
# ...

# %% [markdown]
# #### 4.2  Check for the DataFrame dimensionality with pandas .info() method

# %% [markdown]
# The .info() method in Pandas provides valuable insights about the DataFrame. The information contains the number of columns, column labels, column data types, memory usage, range index, and the number of cells in each column (non-null values). The info() method does not return any value, it prints the information. [[5]](https://www.w3schools.com/python/pandas/ref_df_info.asp)
#
# The output of the .info() method consists of several key components: [[6]](https://machinelearningtutorials.org/a-comprehensive-guide-to-using-the-pandas-dataframe-info-method/)
#
# - The total number of rows (entries) in the DataFrame.
#
# - A summary of each column, including:
#   - The column name
#   - The number of non-null values
#   - The data type of the column
#   - The memory usage of the column
#
# The dataset contains the following columns:
#
# - Date of Sale (dd/mm/yyyy): Date when the property was sold.
#
# - Address: Address of the property.
#
# - County: The county in which the property is located.
#
# - Eircode: Eircode of the property.
#
# - Price in Euro: The sale price of the property in Euros.
#
# - Not Full Market Price: Indicates whether the sale was at the full market price.
#
# - VAT Exclusive: Indicates whether VAT was excluded in the sale price.
#
# - Description of Property: Type of property (e.g., second-hand or new).
#
# - Property Size Description: Description of the property size (e.g., "greater than 125 sq metres").

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 694503 entries, 0 to 694502
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Date of Sale (dd/mm/yyyy)  694503 non-null  object
#  1   Address                    694503 non-null  object
#  2   County                     694503 non-null  object
#  3   Eircode                    166138 non-null  object
#  4   Price in Euro              694503 non-null  float64
#  5   Not Full Market Price      694503 non-null  object
#  6   VAT Exclusive              694503 non-null  object
#  7   Description of Property    694503 non-null  object
#  8   Property Size Description  52830 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 47.7+ MB

# %% [markdown]
# Upon review, I can gather the following information:
#
# - The DataFrame contains 694503 rows and 9 columns.
# - The columns are: "Date of Sale", "Address", "County", "Eircode", "Price in Euro", "Not Full Market Price","VAT Exclusive", "Description of Property" and "Property Size Description".
# - Some columns have non-null values, indicating that there are missing values in this dataset. Two variables of the columns have missing values.
# - One quantitative variables is numeric with type float64: "Price in Euro".
# - Eight qualitative variables are categorical with type object: "Date of Sale", ""Address", "County", "Eircode", "Not Full Market Price","VAT Exclusive", "Description of Property" and "Property Size Description".
# - The memory usage of this DataFrame is approximately 47.7 MB.
#
# ###### [5] [w3schools Pandas DataFrame info() Method](https://www.w3schools.com/python/pandas/ref_df_info.asp)
# ###### [6] [Machine Learning Tutorials: Understanding the .info output - Machine Learning Tutorials](https://machinelearningtutorials.org/a-comprehensive-guide-to-using-the-pandas-dataframe-info-method/)

# %% [markdown]
# #### 4.3  Generate descriptive statistics with pandas df.describe method

# %% [markdown]
# This analysis provides generalized descriptive statistics that summarises the central tendency of the data, the dispersion, and the shape of the dataset’s distribution. It also provides helpful information on missing NaN data. It includes the following statistics: [[7]](https://www.pythonlore.com/exploring-pandas-dataframe-describe-for-descriptive-statistics/)  [[8]](https://pandas.pydata.org/pandas-docs/version/0.20.2/generated/pandas.DataFrame.describe.html)
#
# By default, the describe() function only generates descriptive statistics for numeric columns in a pandas DataFrame. I specifying include='all' which will force pandas to generate summaries for all columns in the dataframe. Some data types don’t have any information. Pandas marks them as NaN.
#
#
# - Count: This represents the number of non-null (non-empty) values in the dataset for each column.
#
# - Unique: This will show the number of unique values in the column
#
# - Top: Ths will display the most common value in the column
#
# - Frequency: This will show the frequency of the top value within the column.
#
# - Mean: This will display the average value for each column.
#
# - Standard deviation: It indicates how spread out the values are around the mean. A higher standard deviation means the values are more spread out from the mean, while a lower standard deviation means the values are closer to the mean.
#
# - Minimum: It represents the lowest value in each column.
#
# - The default percentiles of the describe function are 25th, 50th, and 75th percentile or (0.25, 0.5, and 0.75).
#
# - First quartile (25th percentile): 25% of the data values are below this value.
#
# - Second quartile (50th percentile): It represents the median, the middle value of the dataset.
#
# - Third quartile (75th percentile): 75% of the data values are below this value.
#
# - Maximum: It represents the highest value in the dataset.

# %%
df.describe(include="all")
# Out:
#        Date of Sale (dd/mm/yyyy)               Address  County  Eircode  \
# count                     694503                694503  694503   166138
# unique                      5145                622025      26   160850
# top                   22/12/2014  Broomfield, Midleton  Dublin  D24W9NN
# freq                        1542                    21  217653       34
# mean                         NaN                   NaN     NaN      NaN
# std                          NaN                   NaN     NaN      NaN
# min                          NaN                   NaN     NaN      NaN
# 25%                          NaN                   NaN     NaN      NaN
# 50%                          NaN                   NaN     NaN      NaN
# 75%                          NaN                   NaN     NaN      NaN
# max                          NaN                   NaN     NaN      NaN
#
#         Price in Euro Not Full Market Price VAT Exclusive  \
# ...

# %% [markdown]
# Key interpretations can be made from this function, both for the quantitative and qualitative data.
#
# Null values: Confirming the observations made from .info, the count of the "Eircode" and "Property Size Description" rows does not match the count of values the other columns, indicating missing data.
#
# ###### [7] [PythonLore: Understanding the Output of pandas.DataFrame.describe](https://www.pythonlore.com/exploring-pandas-dataframe-describe-for-descriptive-statistics/)
# ###### [8] [Pandas Documentation: pandas.DataFrame.describe](https://pandas.pydata.org/pandas-docs/version/0.20.2/generated/pandas.DataFrame.describe.html)

# %% [markdown]
# #### 4.4 Check for missing data using df.isna

# %%
print(df.isna().sum())
# Out:
# Date of Sale (dd/mm/yyyy)         0
# Address                           0
# County                            0
# Eircode                      528365
# Price in Euro                     0
# Not Full Market Price             0
# VAT Exclusive                     0
# Description of Property           0
# Property Size Description    641673
# dtype: int64

# %% [markdown]
# Using the dataframe `.isna()` to detect missing values [[9]](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html), there are two of the columns, "Eircode" and "Property Size Description" have missing values. I will keep this in  mind throughout the project.
#
# ###### [9] [Pandas Documentation: pandas.DataFrame.isna](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html)

# %% [markdown]
# ## 5.   Data Analysis
#
# ***

# %% [markdown]
# ### 5.1  Analysis of Property Prices in Ireland (2010-2024)

# %% [markdown]
# Before the analysis, I need to set the `Date of Sale` from Object to datetime. [[10]](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html) [[11]](https://www.geeksforgeeks.org/python-pandas-to_datetime/)   [[12]](https://www.w3schools.com/python/python_datetime.asp)

# %%
df["Date of Sale (dd/mm/yyyy)"]
# Out:
# 0         01/01/2010
# 1         03/01/2010
# 2         04/01/2010
# 3         04/01/2010
# 4         04/01/2010
#              ...
# 694498    22/11/2024
# 694499    22/11/2024
# 694500    22/11/2024
# 694501    22/11/2024
# 694502    22/11/2024
# Name: Date of Sale (dd/mm/yyyy), Length: 694503, dtype: object

# %%
df["Date of Sale"] = pd.to_datetime(df["Date of Sale (dd/mm/yyyy)"], format="%d/%m/%Y")

# %%
df["Date of Sale"]
# Out:
# 0        2010-01-01
# 1        2010-01-03
# 2        2010-01-04
# 3        2010-01-04
# 4        2010-01-04
#             ...
# 694498   2024-11-22
# 694499   2024-11-22
# 694500   2024-11-22
# 694501   2024-11-22
# 694502   2024-11-22
# Name: Date of Sale, Length: 694503, dtype: datetime64[ns]

# %% [markdown]
# I want to add a new column "Year"and "Month" to the DataFrame df by extracting the year/month from the "Date of Sale" column which now contains datetime objects. The dt accessor is used to access datetime-specific properties and methods for columns containing datetime objects. It allows you to extract date components such as the year, month, day, etc.[[13]](https://pandas.pydata.org/docs/reference/api/pandas.Series.dt.year.html) [[14]](https://www.statology.org/how-to-extract-date-components-year-month-day-in-python/)

# %%
df["Year"] = df["Date of Sale"].dt.year
print(df["Year"])
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 694498    2024
# 694499    2024
# 694500    2024
# 694501    2024
# 694502    2024
# Name: Year, Length: 694503, dtype: int32

# %%
df["Month"] = df["Date of Sale"].dt.month
print (df["Month"])
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
#           ..
# 694498    11
# 694499    11
# 694500    11
# 694501    11
# 694502    11
# Name: Month, Length: 694503, dtype: int32

# %% [markdown]
# ###### References
#
# ###### [10] [Pandas Documentation: pandas.to_datetime](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html)
# ###### [11] [GeeksForGeeks: pandas.to_datetime](https://www.geeksforgeeks.org/python-pandas-to_datetime/)
# ###### [12] [w3schools - Python Datetime](https://www.w3schools.com/python/python_datetime.asp)
# ###### [13] [Pandas Pydata: pandas.pydata](https://pandas.pydata.org/docs/reference/api/pandas.Series.dt.year.html)
# ###### [14] [Statology: How to Extract Date Components (Year, Month, Day) in Python](https://www.statology.org/how-to-extract-date-components-year-month-day-in-python/)

# %% [markdown]
# #### 5.1.1 Average property prices by county (2010-2024)

# %% [markdown]
# First, I want to get the average property price by county in Ireland from 2010 to 2024 to date.

# %% [markdown]
# <small>References [[15]](https://seaborn.pydata.org/generated/seaborn.lineplot.html) [[16]](https://medium.com/@mdnu08/automatically-annotate-the-maximum-value-in-a-plot-created-using-the-python-matplotlib-library-54c43001e39c#:~:text=We%20can%20then%20annotate%20the%20maximum%20value%20in%20the%20plot) [[17]](https://www.geeksforgeeks.org/matplotlib-pyplot-annotate-in-python/) [[18]](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.annotate.html)  + Lecture notes, labs & assignments <small>

# %%
avg_price_by_county = df.groupby("County")["Price in Euro"].mean().sort_index().round()
plt.figure(figsize=(12, 6))
sns.set_style("darkgrid")
sns.set_palette("BrBG_r")
ax = sns.lineplot(data=avg_price_by_county, marker="o", label="Avg Price")
plt.title("Average Property Price by County (2010-2024)", family="monospace", fontsize=15)
plt.legend(title="Average Price",loc="center right",bbox_to_anchor=(1, 0, 0.15, 1)) 
plt.xticks(rotation=45)     

max_price = avg_price_by_county.max()                               # Find the max price
max_county = avg_price_by_county.idxmax()                           # Find the county with the max price
ax.annotate("Max Price", 
            (max_county, max_price),                                # Point to annotate
            xytext=(list(avg_price_by_county.index).index(max_county) + 1.1, max_price + 2.9),  # converts the county names to their index positions in the list.
            arrowprops=dict(arrowstyle="-|>",color="black"),        # Arrow properties
            fontsize=11,
            color="black") 

min_price = avg_price_by_county.min()                               # Find the min price
min_county = avg_price_by_county.idxmin()                           # Find the county with the min price
ax.annotate("Min Price", 
            (min_county, min_price),                                # Point to annotate
            xytext=(list(avg_price_by_county.index).index(min_county) -2.9, min_price + 2.9),  # Positioning the text
            arrowprops=dict(arrowstyle="-|>",color="black"),        # Arrow properties
            fontsize=11,
            color="black") 
                    
plt.tight_layout()
plt.show()

# %% [markdown]
# <small>References [[19]](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.idxmax.html) [[20]](https://www.w3schools.com/python/pandas/ref_df_idxmax.asp)<small>

# %%
highest_avg_price_county = avg_price_by_county.idxmax()
highest_avg_price = int(avg_price_by_county.max())
lowest_avg_price_county = avg_price_by_county.idxmin()
lowest_avg_price = int(avg_price_by_county.min())
print(f"{highest_avg_price_county} has the highest average property price in Ireland, with an average price of €{highest_avg_price}.")
print(f"{lowest_avg_price_county} has the lowest average property price in Ireland, with an average price of €{lowest_avg_price}.")
# Out:
# Dublin has the highest average property price in Ireland, with an average price of €467700.
# Leitrim has the lowest average property price in Ireland, with an average price of €122075.

# %% [markdown]
# ###### References
#
# ###### [15] [Seaborn Documentation: seaborn.lineplot](https://seaborn.pydata.org/generated/seaborn.lineplot.html)
#
# ###### [16] [Medium: Automatically Annotate The Maximum Value In A Plot Created Using The Python Matplotlib library](https://medium.com/@mdnu08/automatically-annotate-the-maximum-value-in-a-plot-created-using-the-python-matplotlib-library-54c43001e39c#:~:text=We%20can%20then%20annotate%20the%20maximum%20value%20in%20the%20plot)
#
# ###### [17] [GeeksforGeeks-Matplotlib.pyplot.annotate() in Python](https://www.geeksforgeeks.org/matplotlib-pyplot-annotate-in-python/)
#
# ###### [18] [Matplotlib: matplotlib.pyplot.annotate](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.annotate.html)
#
# ###### [19] [pandas.pydata:pandas.DataFrame.idxmax](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.idxmax.html)
#
# ###### [20] [w3schools: Pandas DataFrame idxmax() Method](https://www.w3schools.com/python/pandas/ref_df_idxmax.asp)

# %% [markdown]
# #### 5.1.2 Number of property sales by county

# %% [markdown]
# Next, I will analyse the numbers of sales per county. Dublin has the highest sales in the last 14 years, with Cork coming in second.

# %% [markdown]
# <small>Reference [[21]](https://seaborn.pydata.org/generated/seaborn.countplot.html)<small>

# %%
sorted_counties = sorted(df["County"].unique())
plt.figure(figsize=(12, 6))
sns.set_style("darkgrid")
sns.set_palette("BrBG_r")
ax = sns.countplot(data=df, x="County", order=sorted_counties, label="Number")
plt.title("Number of Property Sales by County (2010-2024)", family="monospace", fontsize=15)
plt.legend(title="Count of Sales",loc="center right",bbox_to_anchor=(1, 0, 0.15, 1)) 
plt.xticks(rotation=45)                         
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### References
#
# ###### [21] [Seaborn Documentation: seaborn.countplot](https://seaborn.pydata.org/generated/seaborn.countplot.html)

# %% [markdown]
# #### 5.1.3 Average property prices by year (2010-2024)

# %% [markdown]
# The Average Property by Year analysis clearly illustrate the property price crash Ireland faced in 2010-2012. It coincided with the 2009 recession as both had started to develop in late 2008 following the global economic slowdown and credit control tightening. The Irish property bubble was the speculative excess element of a long-term price increase of real estate in the Republic of Ireland from the early 2000s to 2007, a period known as the later part of the Celtic Tiger. The collapse of the property bubble was one of the major contributing factors to the post-2008 Irish banking crisis.[[22]](https://en.wikipedia.org/wiki/Irish_property_bubble)
#
# The regression line trend upwards indicates an overall increase in property prices as we move through the years from 2012 to 2024. Interestingly, a news report on 13 December 2024 suggested that Irish property prices are overvalued by 8% to 10%, according to the Economic and Social Research Institute (ESRI) in its latest Quarterly Economic Commentary [[23]](https://www.rte.ie/news/business/2024/1212/1485932-esri-house-prices/) The report displayed a graph very much in line with the below. The report also stated that property prices rose by 10% over the past year and are now 14% above their boom-time peak in 2007, according to the Central Statistics Office [[24]](https://www.cso.ie/en/statistics/prices/residentialpropertypriceindex/). These observations are very concerning and not sustainable in the longer term.

# %% [markdown]
# <small>Reference [[25]](https://realpython.com/python-seaborn/) [[26]](https://www.geeksforgeeks.org/convert-a-dataframe-column-to-integer-in-pandas/)
# [[27]](https://www.w3schools.com/python/pandas/ref_df_groupby.asp) [[28]](https://www.geeksforgeeks.org/pandas-groupby-one-column-and-get-mean-min-and-max-values/) [[29]](https://seaborn.pydata.org/generated/seaborn.regplot.html) + Lecture notes, labs & assignments<small>

# %%
avg_price_by_year = df.groupby("Year")["Price in Euro"].mean().round().sort_values()

plt.figure(figsize=(13.5, 6))
sns.set_style("darkgrid")
sns.set_palette("BrBG_r")

# sns.regplot requires a DataFrame, so I need to convert the Series to a DataFrame
avg_price_df = avg_price_by_year.reset_index()        # converts a Series into a DataFrame by resetting the index and turning the index into a regular column.
avg_price_df["Year_Num"] = pd.to_numeric(avg_price_df["Year"]) # creates a new column called "Year_Num" by converting the values in the "Year" column to numeric format 

ax = sns.lineplot(data=avg_price_by_year, marker="o", label="Avg Price")  # plot line chart
sns.regplot(x="Year_Num", y="Price in Euro", data=avg_price_df, scatter=False, ci=None, color="red", label="Regression Line") # Add regression line

plt.title("Average Property Price by Year (2010-2024)", family="monospace", fontsize=15)
plt.legend(title="Average Price", loc="center right", bbox_to_anchor=(1, 0, 0.15, 1))
plt.xticks(avg_price_df["Year_Num"], avg_price_df["Year"], rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### References
#
# ###### [22] [Wikipedia: Irish property bubble](https://en.wikipedia.org/wiki/Irish_property_bubble)
# ###### [23] [RTE report: House prices overvalued by 8-10%, ESRI warns in latest economic update](https://www.rte.ie/news/business/2024/1212/1485932-esri-house-prices/)
# ###### [24] [Central Statistics Office: Residential Property Price Index](https://www.cso.ie/en/statistics/prices/residentialpropertypriceindex/)
# ###### [25] [Real Python: Visualizing Data in Python With Seaborn](https://realpython.com/python-seaborn/)
# ###### [26] [GeeksforGeeks: Convert Dataframe Column to Integer using to_numeric() Method](https://www.geeksforgeeks.org/convert-a-dataframe-column-to-integer-in-pandas/)
# ###### [27] [w3schools: Pandas DataFrame groupby() Method](https://www.w3schools.com/python/pandas/ref_df_groupby.asp)
# ###### [28] [GeekforGeeks: Pandas – GroupBy One Column and Get Mean, Min, and Max values](https://www.geeksforgeeks.org/pandas-groupby-one-column-and-get-mean-min-and-max-values/)
# ###### [29] [seaborn.pydata: seaborn.regplot](https://seaborn.pydata.org/generated/seaborn.regplot.html)

# %% [markdown]
# #### 5.1.4 Average property prices by month (2010-2024)

# %% [markdown]
# The average property price by month indicates that January and May are the best months to purchase property as on average they have the lowest prices. September has the highest average property month.

# %% [markdown]
# <small>References [[30]](https://www.geeksforgeeks.org/reindexing-in-pandas-dataframe/) [[31]](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reindex.html) [[32]](https://pandas.pydata.org/docs/reference/api/pandas.Index.map.html) [[33]](https://realpython.com/python-map-function/) + Lecture notes, labs & assignments<small>

# %%
month_names = {1: "Jan", 2: "Feb", 3: "Mar", 4: "Apr",5: "May", 6: "Jun", 7: "Jul", 8: "Aug",9: "Sep", 10: "Oct", 11: "Nov", 12: "Dec"}
avg_price_by_month = df.groupby("Month")["Price in Euro"].mean().round()
avg_price_by_month = avg_price_by_month.reindex(sorted(avg_price_by_month.index))  # Sort the months by their numeric order
avg_price_by_month.index = avg_price_by_month.index.map(month_names)   # Replace numerical indices with month names
plt.figure(figsize=(12, 6))
sns.set_style("darkgrid")
sns.set_palette("BrBG_r")
ax = sns.lineplot(data=avg_price_by_month, marker="o", label="Avg Price")
plt.title("Average Property Price by Month (2010-2024)", family="monospace", fontsize=15)
plt.legend(title="Average Price",loc="center right",bbox_to_anchor=(1, 0, 0.15, 1)) 
plt.xticks(rotation=45)                         
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### References
#
# ###### [30] [GeeksforGeeks: Reindexing in Pandas DataFrame](https://www.geeksforgeeks.org/reindexing-in-pandas-dataframe/)
# ###### [31] [Pandas Documentation: pandas.pydata:pandas.DataFrame.reindex](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reindex.html)
# ###### [32] [Pandas Documentation: pandas.pydata:pandas.Index.map](https://pandas.pydata.org/docs/reference/api/pandas.Index.map.html)
# ###### [33] [Real Python: Python's map() ](https://realpython.com/python-map-function/)

# %% [markdown]
# #### 5.1.5 Number of occurrences of each property type

# %% [markdown]
# Even though the supply of second-hand properties for sale has fallen by almost a third since the pandemic, according to estate agent Sherry FitzGerald. [[34]](https://www.sherryfitz.ie/), the below analysis indicates that this segment of the market is still the largest in Ireland.

# %% [markdown]
# <small>Reference [[21]](https://seaborn.pydata.org/generated/seaborn.countplot.html)<small>

# %%
plt.figure(figsize=(12, 6))
sns.set_style("darkgrid")
sns.set_palette("BrBG_r")
ax = sns.countplot(data=df, x="Description of Property", label="Number")
plt.title("Number Of Occurences Of Each Property Type (2010-2024)", family="monospace", fontsize=15)
plt.legend(title="Count of Sales",loc="center right",bbox_to_anchor=(1, 0, 0.15, 1)) 
plt.xticks(rotation=45)                         
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### References
#
# ###### [34] [Sherry FitzGerald](https://www.sherryfitz.ie/)
#
# ###### [21] [seaborn.countplot](https://seaborn.pydata.org/generated/seaborn.countplot.html)

# %% [markdown]
# #### 5.1.6 Average property prices by property type (2010-2024)

# %% [markdown]
# The property price by property type is interesting as the cost of a second hand dwelling is not far behind a new dwelling. An article in the Irish Times said the “severe scarcity” of homes to buy was aggravating affordability. “The shortage of housing in the lower price categories is particularly alarming,” Sherry FitzGerald managing director Marian Finnegan. [[35]](https://www.irishtimes.com/business/2024/08/20/supply-of-second-hand-homes-for-sale-down-by-a-third-since-pandemic/)

# %%
avg_price_by_property_type = df.groupby("Description of Property")["Price in Euro"].mean().round().sort_values()
plt.figure(figsize=(12, 6))
sns.set_style("darkgrid")
sns.set_palette("BrBG_r")
ax = sns.lineplot(data=avg_price_by_property_type, marker="o", label="Avg Price")
plt.title("Average Property Price by Property Type (2010-2024)", family="monospace", fontsize=15)
plt.legend(title="Average Price",loc="center right",bbox_to_anchor=(1, 0, 0.15, 1)) 
plt.xticks(rotation=45)                         
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### References
#
# ###### [35] [Irish Times: Supply of second-hand homes for sale down by a third since pandemic](https://www.irishtimes.com/business/2024/08/20/supply-of-second-hand-homes-for-sale-down-by-a-third-since-pandemic/)

# %% [markdown]
# #### 5.1.7 Full Market price comparison

# %% [markdown]
# I contacted the Property Services Regulatory Authority about the definition of the "Not Market Price" column. I got a quick response from Catriona.
# She states "In a small number of transactions included in the Register the price shown does not represent the full market price of the property concerned for a variety of reasons e.g. it could be that the house was sold for less than full market price in a deal between family or a partner buys out another partners share of the house etc. The reason is not known why a house is sold for less than full market price. All such properties are market ** on the property price register and "not full market price" should state "Yes"." [[36]](https://www.psr.ie/about-us/contact-us/)
# The below pie chart illustrates that 5% of property in Ireland are sold below Market value.

# %% [markdown]
# <small>Reference [[37]](https://www.statology.org/seaborn-pie-chart/) [[38]](https://www.geeksforgeeks.org/how-to-create-a-pie-chart-in-seaborn/) + Lecture notes, labs & assignments<small>

# %%
full_market_price_counts = df["Not Full Market Price"].value_counts()
explode = (0.1, 0.2)          # the explode will help to separate the two elements
palette_colour=sns.color_palette("BrBG_r",n_colors=2)
plt.figure(figsize=(12, 6))
plt.pie(full_market_price_counts, labels=full_market_price_counts.index, autopct="%1.1f%%", colors=palette_colour, startangle=370, explode=explode, shadow=True)
plt.legend(title="Full Market Price",loc="best",bbox_to_anchor=(1, 0, 0.15, 1)) 
plt.title("Full Market Price vs Not Full Market Price", family="monospace", fontsize=15)
plt.show()

# %% [markdown]
# ###### References
#
# ###### [36] [Property Services Regulatory Authority: Employee Quotation](https://www.psr.ie/about-us/contact-us/)
#
# ###### [37] [Statology: How to Create a Pie Chart in Seaborn](https://www.statology.org/seaborn-pie-chart/)
#
# ###### [38] [GeeksforGeeks: How to Create a Pie Chart in Seaborn?](https://www.geeksforgeeks.org/how-to-create-a-pie-chart-in-seaborn/)

# %% [markdown]
# ### 5.2 Analysis of Property Prices for all years in Mayo (2010-2024)

# %% [markdown]
# #### 5.2.1 Data Preparation for Analysis

# %% [markdown]
# I need to extract the Mayo data from the DataFrame and create a new DataFrame with only Mayo data.

# %% [markdown]
# <small>Reference [[39]](https://blog.grippybyte.com/extract-data-from-dataframe-in-python)<small>

# %%
df_mayo = df[df["County"] == "Mayo"]
#print(df_mayo)

# %% [markdown]
# Before the analysis, I need to set the `Date of Sale` from Object to datetime.

# %%
df_mayo["Date of Sale (dd/mm/yyyy)"]
# Out:
# 30        04/01/2010
# 35        04/01/2010
# 46        05/01/2010
# 232       11/01/2010
# 246       11/01/2010
#              ...
# 694316    20/11/2024
# 694366    20/11/2024
# 694442    21/11/2024
# 694460    22/11/2024
# 694476    22/11/2024
# Name: Date of Sale (dd/mm/yyyy), Length: 16667, dtype: object

# %%
df_mayo["Date of Sale"] = pd.to_datetime(df_mayo["Date of Sale (dd/mm/yyyy)"], format="%d/%m/%Y")
# Out:
# C:\Users\curleys\AppData\Local\Temp\ipykernel_4408\1248909470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mayo["Date of Sale"] = pd.to_datetime(df_mayo["Date of Sale (dd/mm/yyyy)"], format="%d/%m/%Y")

# %%
df_mayo["Date of Sale"]
# Out:
# 30       2010-01-04
# 35       2010-01-04
# 46       2010-01-05
# 232      2010-01-11
# 246      2010-01-11
#             ...
# 694316   2024-11-20
# 694366   2024-11-20
# 694442   2024-11-21
# 694460   2024-11-22
# 694476   2024-11-22
# Name: Date of Sale, Length: 16667, dtype: datetime64[ns]

# %% [markdown]
# Set the index to datetime

# %%
df_mayo.set_index("Date of Sale", inplace=True)

# %% [markdown]
# #### 5.2.2 Average Mayo Property Price by Year (2010-2024)

# %% [markdown]
# The average house price in Mayo is increasing year upon year from 2017. It is interesting to note that recovery following the crash was slower in Mayo (2017) than nationally (2012). [40] Refer to section 5.1.3 - Average property prices by year (2010-2024).
#
# According to the latest Daft.ie House Price Report, housing prices in Mayo have risen by nine percent in the past year. [[41]](https://mcusercontent.com/7dc574a8b74605f879edb49d5/files/fb787d2b-e69f-a3f9-e8ae-666fea2e5205/House_Price_Report_Q3_2024.pdf)

# %% [markdown]
# <small>Reference [[42]](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html) [[43]](https://www.statology.org/python-resample-time-series/) [[44]](https://matplotlib.org/stable/api/dates_api.html) [[45]](https://www.geeksforgeeks.org/matplotlib-dates-datestr2num-in-python/?ref=ml_lbp) [[16]](https://medium.com/@mdnu08/automatically-annotate-the-maximum-value-in-a-plot-created-using-the-python-matplotlib-library-54c43001e39c#:~:text=We%20can%20then%20annotate%20the%20maximum%20value%20in%20the%20plot) [[17]](https://www.geeksforgeeks.org/matplotlib-pyplot-annotate-in-python/)
# [[18]](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.annotate.html)+ Lecture notes, labs & assignments<small>

# %%
yearly_mayo = df_mayo["Price in Euro"].resample("YE").mean().round()
plt.figure(figsize=(12, 6))
sns.set_style("darkgrid")
sns.set_palette("BrBG_r")
ax = sns.lineplot(data=yearly_mayo, marker="o", label="Avg Price")
ax.set(xlabel="Date", ylabel="Average Price")
plt.title("Average Mayo Property Price By Year", family="monospace", fontsize=15)
plt.legend(title="Average Price",loc="center right",bbox_to_anchor=(1, 0, 0.15, 1)) 
plt.xticks(rotation=45)  

max_price = yearly_mayo.max()                           # Find the max price
max_year = yearly_mayo.idxmax()                         # Find the county with the max price
max_year_num = mdates.date2num(max_year)                # Convert max_year to its numerical equivalent for shifting

ax.annotate(
    "Max Price",
    xy=(max_year, max_price),
    xytext=(max_year_num -700, max_price + 2),          # Small upward shift
    arrowprops=dict(arrowstyle="-|>", color="black"),
    fontsize=11,
    color="black",
    horizontalalignment="center")

min_price = yearly_mayo.min()                           # Find the min price
min_year = yearly_mayo.idxmin()                         # Find the county with the min price
min_year_num = mdates.date2num(min_year)                # Convert max_year to its numerical equivalent for shifting

ax.annotate(
    "Min Price",
    xy=(min_year, min_price),
    xytext=(max_year_num - 2900, min_price - 2.5),      # Small downward shift
    arrowprops=dict(arrowstyle="-|>", color="black"),
    fontsize=11,
    color="black",
    horizontalalignment="center")                 

plt.tight_layout()
plt.show()

# %% [markdown]
# ###### References
#
# ###### [39] [Blog.grippybyte: Extract data from DataFrame in Python](https://blog.grippybyte.com/extract-data-from-dataframe-in-python)
#
# ###### [40] [5.1.3 Average property prices by year (2010-2024)]()
#
# ###### [41] [The Daft.ie House Price Report Q3 2024](https://mcusercontent.com/7dc574a8b74605f879edb49d5/files/fb787d2b-e69f-a3f9-e8ae-666fea2e5205/House_Price_Report_Q3_2024.pdf)
#
# ###### [42] [pandas.pydata: pandas.DataFrame.resample](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html)
#
# ###### [43] [Statology: How to Resample Time Series Data in Python (With Examples)](https://www.statology.org/python-resample-time-series/)
#
# ###### [44] [matplotlib.dates](https://matplotlib.org/stable/api/dates_api.html)
#
# ###### [45] [Matplotlib.dates.datestr2num() in Python](https://www.geeksforgeeks.org/matplotlib-dates-datestr2num-in-python/?ref=ml_lbp)
#
# ###### [16] [Medium: Automatically Annotate The Maximum Value In A Plot Created Using The Python Matplotlib library](https://medium.com/@mdnu08/automatically-annotate-the-maximum-value-in-a-plot-created-using-the-python-matplotlib-library-54c43001e39c#:~:text=We%20can%20then%20annotate%20the%20maximum%20value%20in%20the%20plot)
#
# ###### [17] [GeeksforGeeks-Matplotlib.pyplot.annotate() in Python](https://www.geeksforgeeks.org/matplotlib-pyplot-annotate-in-python/)
#
# ###### [18] [matplotlib.pyplot.annotate](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.annotate.html)

# %% [markdown]
# #### 5.2.3 Average Mayo Property Price by Month (2010-2024)

# %% [markdown]
# The following graph is in line with the trend observed for the yearly data. There are no major outliers in the data.

# %% [markdown]
# <small>Reference [[42]](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html) [[43]](https://www.statology.org/python-resample-time-series/) [[16]](https://medium.com/@mdnu08/automatically-annotate-the-maximum-value-in-a-plot-created-using-the-python-matplotlib-library-54c43001e39c#:~:text=We%20can%20then%20annotate%20the%20maximum%20value%20in%20the%20plot) [[17]](https://www.geeksforgeeks.org/matplotlib-pyplot-annotate-in-python/)
# [[18]](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.annotate.html)+ Lecture notes, labs & assignments<small>+ Lecture notes, labs & assignments<small>

# %%
monthly_mayo = df_mayo["Price in Euro"].resample("ME").mean().round()
plt.figure(figsize=(12, 6))
sns.set_style("darkgrid")
sns.set_palette("BrBG_r")
ax = sns.lineplot(data=monthly_mayo, marker="o", label="Avg Price")
ax.set(xlabel="Date", ylabel="Average Price")
plt.title("Average Mayo Property Price By Month", family="monospace", fontsize=15)
plt.legend(title="Average Price",loc="center right",bbox_to_anchor=(1, 0, 0.15, 1)) 
plt.xticks(rotation=45)  

max_price = monthly_mayo.max()                              # Find the max price
max_month = monthly_mayo.idxmax()                           # Find the county with the max price
max_month_num = mdates.date2num(max_month)                  # Convert max_year to its numerical equivalent for shifting

ax.annotate(
    "Max Price",
    xy=(max_month, max_price),
    xytext=(max_month_num -500, max_price + 2),             # Small upward shift
    arrowprops=dict(arrowstyle="-|>", color="black"),
    fontsize=11,
    color="black",
    horizontalalignment="center")

min_price = monthly_mayo.min()                              # Find the min price
min_month = monthly_mayo.idxmin()                           # Find the county with the min price
min_month_num = mdates.date2num(min_month)                  # Convert max_year to its numerical equivalent for shifting

ax.annotate(
    "Min Price",
    xy=(min_month, min_price),
    xytext=(max_month_num - 3600, min_price - 2.5),         # Small downward shift
    arrowprops=dict(arrowstyle="-|>", color="black"),
    fontsize=11,
    color="black",
    horizontalalignment="center")     

plt.tight_layout()
plt.show()

# %% [markdown]
# ###### References
#
# ###### [42] [Pandas Documentation: pandas.pydata: pandas.DataFrame.resample](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html)
#
# ###### [43] [Statology: How to Resample Time Series Data in Python (With Examples)](https://www.statology.org/python-resample-time-series/)
#
# ###### [16] [Medium: Automatically Annotate The Maximum Value In A Plot Created Using The Python Matplotlib library](https://medium.com/@mdnu08/automatically-annotate-the-maximum-value-in-a-plot-created-using-the-python-matplotlib-library-54c43001e39c#:~:text=We%20can%20then%20annotate%20the%20maximum%20value%20in%20the%20plot)
#
# ###### [17] [GeeksforGeeks-Matplotlib.pyplot.annotate() in Python](https://www.geeksforgeeks.org/matplotlib-pyplot-annotate-in-python/)
#
# ###### [18] [matplotlib.pyplot.annotate](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.annotate.html)

# %% [markdown]
# #### 5.2.4 Average Mayo Property Price by month (2024)

# %% [markdown]
# I need to extract the 2024 data from the DataFrame and create a new DataFrame with only Mayo data in 2024.

# %% [markdown]
# <small>Reference [[39]](https://blog.grippybyte.com/extract-data-from-dataframe-in-python)<small>

# %%
df_mayo_2024=df_mayo[df_mayo.index.year==2024]
#print(df_mayo_2024)

# %% [markdown]
# Before the analysis, I need to set the `Date of Sale` from Object to datetime.

# %%
df_mayo_2024["Date of Sale (dd/mm/yyyy)"]
# Out:
# Date of Sale
# 2024-01-02    02/01/2024
# 2024-01-02    02/01/2024
# 2024-01-03    03/01/2024
# 2024-01-03    03/01/2024
# 2024-01-03    03/01/2024
#                  ...
# 2024-11-20    20/11/2024
# 2024-11-20    20/11/2024
# 2024-11-21    21/11/2024
# 2024-11-22    22/11/2024
# 2024-11-22    22/11/2024
# Name: Date of Sale (dd/mm/yyyy), Length: 1170, dtype: object

# %%
df_mayo_2024["Date of Sale"] = pd.to_datetime(df_mayo_2024["Date of Sale (dd/mm/yyyy)"], format="%d/%m/%Y")
#print(df_mayo_2024)
# Out:
# C:\Users\curleys\AppData\Local\Temp\ipykernel_836\3094776764.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mayo_2024["Date of Sale"] = pd.to_datetime(df_mayo_2024["Date of Sale (dd/mm/yyyy)"], format="%d/%m/%Y")

# %%
df_mayo_2024["Date of Sale"]
# Out:
# Date of Sale
# 2024-01-02   2024-01-02
# 2024-01-02   2024-01-02
# 2024-01-03   2024-01-03
# 2024-01-03   2024-01-03
# 2024-01-03   2024-01-03
#                 ...
# 2024-11-20   2024-11-20
# 2024-11-20   2024-11-20
# 2024-11-21   2024-11-21
# 2024-11-22   2024-11-22
# 2024-11-22   2024-11-22
# Name: Date of Sale, Length: 1170, dtype: datetime64[ns]

# %% [markdown]
# Set the new datetime column as the index

# %%
df_mayo_2024.set_index("Date of Sale", inplace=True)

# %% [markdown]
# Below we can see the mean monthly property price for property in Mayo during 2024. The house prices peaked in August.

# %% [markdown]
# <small> References [[15]](https://seaborn.pydata.org/generated/seaborn.lineplot.html) [[42]](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html) [[43]](https://www.statology.org/python-resample-time-series/)<small>

# %%
monthly_mayo_2024 = df_mayo_2024["Price in Euro"].resample("ME").mean().round()
plt.figure(figsize=(12, 6))
sns.set_style("darkgrid")
sns.set_palette("BrBG_r")
ax = sns.lineplot(data=monthly_mayo_2024, marker="o", label="Avg Price")
ax.set(xlabel="Date", ylabel="Average Price")
plt.title("Average Mayo Property Price in 2024", family="monospace", fontsize=15)
plt.legend(title="Average Price",loc="center right",bbox_to_anchor=(1, 0, 0.15, 1)) 
ax.xaxis.set_major_formatter(mdates.DateFormatter('%B'))        # # '%B' for full month name  matplotlib.dates.DateFormatter
plt.xticks(rotation=45)  
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### References
#
# ###### [39] [Blog.grippybyte: Extract data from DataFrame in Python](https://blog.grippybyte.com/extract-data-from-dataframe-in-python)
#
# ###### [15] [seaborn.lineplot](https://seaborn.pydata.org/generated/seaborn.lineplot.html)
#
# ###### [42] [Pandas Documentation: pandas.pydata: pandas.DataFrame.resample](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html)
#
# ###### [43] [Statology: How to Resample Time Series Data in Python (With Examples)](https://www.statology.org/python-resample-time-series/)

# %% [markdown]
# #### 5.2.5 Number of property sales in Mayo in 2024

# %% [markdown]
# There were 1170 properties sold in County Mayo during 2024

# %% [markdown]
# <small> References [[46]](https://www.statology.org/pandas-value_counts-sort/) [[47]](https://www.restack.io/p/pandas-knowledge-value-counts-sort)<small>

# %%
mayo_counts = df_mayo_2024["County"].value_counts().sort_values()
print(mayo_counts)
# Out:
# County
# Mayo    1170
# Name: count, dtype: int64

# %% [markdown]
# ###### References
#
# ###### [46] [Statology: Pandas Value Counts Sort Explained](https://www.statology.org/pandas-value_counts-sort/)
#
# ###### [47] [Restack: How to Sort Results of value_counts()](https://www.restack.io/p/pandas-knowledge-value-counts-sort)

# %% [markdown]
# #### 5.2.6 Number of occurrences of each property type in Mayo (2024)

# %% [markdown]
# Even with the fall in availability of second-hand homes coming on to the market over the last year, this segment accounts for the majority of sales in County Mayo in 2024. The number of new homes is shockingly low. Economist at Trinity College Dublin, Ronan Lyons, said "The underlying issue remains a lack of homes, of all kinds, and this should remain the focus for policymakers before and after the next election” [[48]](https://www.mayonews.ie/news/local-news/1617692/mayo-housing-prices-continue-to-rise-as-shortages-persists.html)

# %% [markdown]
# <small> References [[46]](https://www.statology.org/pandas-value_counts-sort/) [[47]](https://www.restack.io/p/pandas-knowledge-value-counts-sort) [[49]](https://seaborn.pydata.org/generated/seaborn.barplot.html)<small>

# %%
description_of_property_counts_mayo = df_mayo_2024["Description of Property"].value_counts().sort_values()
plt.figure(figsize=(10, 6))
sns.set_style("darkgrid")
sns.set_palette("BrBG_r")
ax = sns.countplot(data=df_mayo_2024, x="Description of Property", label="Number")
plt.title("Number Of Occurences of Each Property Type 2024", family="monospace", fontsize=15)
plt.legend(title="Count of Sales",loc="center right",bbox_to_anchor=(1, 0, 0.15, 1)) 
plt.xticks(rotation=360, ha="center")                        
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### References
#
# ###### [46] [Statology: Pandas Value Counts Sort Explained](https://www.statology.org/pandas-value_counts-sort/)
#
# ###### [47] [Restack: How to Sort Results of value_counts()](https://www.restack.io/p/pandas-knowledge-value-counts-sort)
#
# ###### [48] [Mayo News:Mayo housing prices continue to rise as shortages persists 30SEPT24)](https://www.mayonews.ie/news/local-news/1617692/mayo-housing-prices-continue-to-rise-as-shortages-persists.html)
#
# ###### [49] [Seaborn.pydata: seaborn.barplot](https://seaborn.pydata.org/generated/seaborn.barplot.html)

# %% [markdown]
# #### 5.2.7 Average proprety price by property type in Mayo in 2024

# %% [markdown]
# The average property price by property type in Mayo is 211,878 Euros for Second-Hand Dwelling house /Apartments and 374,523
# for New Dwelling house /Apartment.

# %% [markdown]
# <small> References [[49]](https://seaborn.pydata.org/generated/seaborn.barplot.html)<small>

# %%
avg_price_by_property_type_mayo = df_mayo_2024.groupby("Description of Property")["Price in Euro"].mean().round().sort_values()
plt.figure(figsize=(10, 6))
sns.set_style("darkgrid")
sns.set_palette("BrBG_r")
sns.barplot(x=avg_price_by_property_type_mayo.index, y=avg_price_by_property_type_mayo.values,label="Avg Price")
plt.title("Average Property Price by Property Type in Mayo 2024", family="monospace", fontsize=15)
plt.legend(title="Average Price",loc="center right",bbox_to_anchor=(1, 0, 0.15, 1)) 
plt.xticks(rotation=360, ha="center")                  
plt.tight_layout()
plt.show()
print(avg_price_by_property_type_mayo)
# Out:
# Description of Property
# Second-Hand Dwelling house /Apartment    211878.0
# New Dwelling house /Apartment            374523.0
# Name: Price in Euro, dtype: float64

# %% [markdown]
# ###### References
#
# ###### [49] [Seaborn.pydata: seaborn.barplot](https://seaborn.pydata.org/generated/seaborn.barplot.html)

# %% [markdown]
# #### 5.2.8  Full Market price comparison in Mayo

# %% [markdown]
# The below pie chart illustrates that 2.6% of property in Mayo are sold below Market value.

# %% [markdown]
# <small> References [[46]](https://www.statology.org/pandas-value_counts-sort/) [[47]](https://www.restack.io/p/pandas-knowledge-value-counts-sort)<small>

# %%
full_market_price_counts_mayo = df_mayo_2024["Not Full Market Price"].value_counts()
print(full_market_price_counts_mayo)
# Out:
# Not Full Market Price
# No     1140
# Yes      30
# Name: count, dtype: int64

# %% [markdown]
# <small> References [[37]](https://www.statology.org/seaborn-pie-chart/) [[38]](https://www.geeksforgeeks.org/how-to-create-a-pie-chart-in-seaborn/)<small>

# %%
full_market_price_counts_mayo = df_mayo_2024["Not Full Market Price"].value_counts()
explode = (0.1, 0.2)          # the explode will help to separate the two elements
palette_colour=sns.color_palette("BrBG_r",n_colors=2)
plt.figure(figsize=(12, 6))
plt.pie(full_market_price_counts_mayo, labels=full_market_price_counts.index, autopct="%1.1f%%", colors=palette_colour, startangle=370, explode=explode, shadow=True)
plt.legend(title="Full Market Price",loc="best",bbox_to_anchor=(1, 0, 0.15, 1)) 
plt.title("Full Market Price vs Not Full Market Price", family="monospace", fontsize=15)
plt.show()

# %% [markdown]
# ###### References
#
# ###### [37] [Statology: How to Create a Pie Chart in Seaborn](https://www.statology.org/seaborn-pie-chart/)
#
# ###### [38] [GeeksforGeeks: How to Create a Pie Chart in Seaborn?](https://www.geeksforgeeks.org/how-to-create-a-pie-chart-in-seaborn/)
#
# ###### [46] [Statology: Pandas Value Counts Sort Explained](https://www.statology.org/pandas-value_counts-sort/)
#
# ###### [47] [Restack: How to Sort Results of value_counts()](https://www.restack.io/p/pandas-knowledge-value-counts-sort)

# %% [markdown]
# ### 5.3 Analysis of Property Prices in Castlebar in 2024

# %% [markdown]
# I filtered the rows in the dataFrame (df_mayo_2024) based on whether the "Address" column contains the substring "Castlebar".

# %% [markdown]
# <small> References [[50]](https://devsolus.com/2024/10/29/filtering-a-pandas-dataframe-string-column-using-the-str-contains-method/) [[51]](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.contains.html) [[52]](https://www.w3schools.com/python/python_regex.asp) [[53]](https://www.geeksforgeeks.org/python-raw-strings/) [[54]](https://pythonguides.com/python-numpy-shape/) [[55]](https://pytutorial.com/python-pandas-shape-quick-dataframe-dimensions/?utm_content=cmp-true)<small>

# %%
df_castlebar_addresses = df_mayo_2024 [df_mayo_2024 ["Address"].str.contains(r"Castlebar", case=False, na=False)] # not case sensitive / replaces NaN values with False / r prefix = a raw string
average_price = df_castlebar_addresses["Price in Euro"].mean()
castlebar_count = df_castlebar_addresses.shape[0]
print(f"The average price of a property in Castlebar in 2024 was €{average_price:,.2f}")
print(f"The number of properties sold in Castlebar during 2024 was {castlebar_count}")
# Out:
# The average price of a property in Castlebar in 2024 was €238,139.98
# The number of properties sold in Castlebar during 2024 was 247

# %% [markdown]
# ###### References
#
# ###### [50] [Devsolus:filtering a pandas dataframe string column using the `str.contains` method ](https://devsolus.com/2024/10/29/filtering-a-pandas-dataframe-string-column-using-the-str-contains-method/)
# ###### [51] [pandas.pydata:pandas.Series.str.contains](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.contains.html)
# ###### [52] [w3schools: Python RegEx](https://www.w3schools.com/python/python_regex.asp)
# ###### [53] [GeeksForGeeks: Python Raw Strings](https://www.geeksforgeeks.org/python-raw-strings/)
# ###### [54] [Pytutorial: Python Pandas shape: Quick DataFrame Dimensions](https://pytutorial.com/python-pandas-shape-quick-dataframe-dimensions/?utm_content=cmp-true)
# ###### [55] [PythonGuide: NumPy shape in Python 3 Examples](https://pythonguides.com/python-numpy-shape/)

# %% [markdown]
# ### 6.  Project References
# ***
#
# ###### [1] [Central Statistics Office: Residential Property Price Index July 2024](https://www.cso.ie/en/releasesandpublications/ep/p-rppi/residentialpropertypriceindexjuly2024/backgroundnotes/)
# ###### [2] [Property Services Regulatory Authority: Residential Property Price Register](https://www.propertypriceregister.ie/)
# ###### [3] [GeeksforGeeks: Pandas read_csv: low_memory and dtype options](https://www.geeksforgeeks.org/pandas-read_csv-low_memory-and-dtype-options/)
# ###### [4] [Stack Overflow - Mixed types when reading csv files. Causes, fixes and consequences](https://stackoverflow.com/questions/25488675/mixed-types-when-reading-csv-files-causes-fixes-and-consequences)
# ###### [5] [w3schools Pandas DataFrame info() Method](https://www.w3schools.com/python/pandas/ref_df_info.asp)
# ###### [6] [Understanding the .info output - Machine Learning Tutorials](https://machinelearningtutorials.org/a-comprehensive-guide-to-using-the-pandas-dataframe-info-method/)
# ###### [7] [Understanding the Output of pandas.DataFrame.describe](https://www.pythonlore.com/exploring-pandas-dataframe-describe-for-descriptive-statistics/)
# ###### [8] [Pandas Documentation on pandas.DataFrame.describe](https://pandas.pydata.org/pandas-docs/version/0.20.2/generated/pandas.DataFrame.describe.html)
# ###### [9] [pandas.DataFrame.isna](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html)
# ###### [10] [pandas.to_datetime](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html)
# ###### [11] [pandas.to_datetime](https://www.geeksforgeeks.org/python-pandas-to_datetime/)
# ###### [12] [w3schools - Python Datetime](https://www.w3schools.com/python/python_datetime.asp)
# ###### [13] [pandas.pydata](https://pandas.pydata.org/docs/reference/api/pandas.Series.dt.year.html)
# ###### [14] [How to Extract Date Components (Year, Month, Day) in Python](https://www.statology.org/how-to-extract-date-components-year-month-day-in-python/)
# ###### [15] [seaborn.lineplot](https://seaborn.pydata.org/generated/seaborn.lineplot.html)
# ###### [16] [Automatically Annotate The Maximum Value In A Plot Created Using The Python Matplotlib library](https://medium.com/@mdnu08/automatically-annotate-the-maximum-value-in-a-plot-created-using-the-python-matplotlib-library-54c43001e39c#:~:text=We%20can%20then%20annotate%20the%20maximum%20value%20in%20the%20plot)
# ###### [17] [GeeksforGeeks-Matplotlib.pyplot.annotate() in Python](https://www.geeksforgeeks.org/matplotlib-pyplot-annotate-in-python/)
# ###### [18] [matplotlib.pyplot.annotate](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.annotate.html)
# ###### [19] [pandas.pydata:pandas.DataFrame.idxmax](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.idxmax.html)
# ###### [20] [w3schools: Pandas DataFrame idxmax() Method](https://www.w3schools.com/python/pandas/ref_df_idxmax.asp)
# ###### [21] [seaborn.countplot](https://seaborn.pydata.org/generated/seaborn.countplot.html)
# ###### [22] [Wikipedia: Irish property bubble](https://en.wikipedia.org/wiki/Irish_property_bubble)
# ###### [23] [RTE report: House prices overvalued by 8-10%, ESRI warns in latest economic update](https://www.rte.ie/news/business/2024/12121485932-esri-house-prices/)
# ###### [24] [Central Statistics Office: Residential Property Price Index](https://www.cso.ie/en/statistics/prices/residentialpropertypriceindex/)
# ###### [25] [Real Python: Visualizing Data in Python With Seaborn](https://realpython.com/python-seaborn/)
# ###### [26] [GeeksforGeeks: Convert Dataframe Column to Integer using to_numeric() Method](https://www.geeksforgeeks.org/convert-a-dataframe-column-to-integer-in-pandas/)
# ###### [27] [w3schools: Pandas DataFrame groupby() Method](https://www.w3schools.com/python/pandas/ref_df_groupby.asp)
# ###### [28] [GeekforGeeks: Pandas – GroupBy One Column and Get Mean, Min, and Max values](https://www.geeksforgeeks.org/pandas-groupby-one-column-and-get-mean-min-and-max-values/)
# ###### [29] [seaborn.pydata: seaborn.regplot](https://seaborn.pydata.org/generated/seaborn.regplot.html)
# ###### [30] [GeeksforGeeks: Reindexing in Pandas DataFrame](https://www.geeksforgeeks.org/reindexing-in-pandas-dataframe/)
# ###### [31] [pandas.pydata:pandas.DataFrame.reindex](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reindex.html)
# ###### [32] [pandas.pydata:pandas.Index.map](https://pandas.pydata.org/docs/reference/api/pandas.Index.map.html)
# ###### [33] [Real Python: Python's map() ](https://realpython.com/python-map-function/3)
# ###### [34] [Sherry FitzGerald](https://www.sherryfitz.ie/)
# ###### [35] [Irish Times: Supply of second-hand homes for sale down by a third since pandemic](https://www.irishtimes.com/business/2024/08/20/supply-of-second-hand-homes-for-sale-down-by-a-third-since-pandemic/)
# ###### [36] [Property Services Regulatory Authority](https://www.psr.ie/about-us/contact-us/)
# ###### [37] [Statology: How to Create a Pie Chart in Seaborn](https://www.statology.org/seaborn-pie-chart/)
# ###### [38] [GeeksforGeeks: How to Create a Pie Chart in Seaborn?](https://www.geeksforgeeks.org/how-to-create-a-pie-chart-in-seaborn/)
# ###### [39] [Extract data from DataFrame in Python](https://blog.grippybyte.com/extract-data-from-dataframe-in-python)
# ###### [40] [5.1.3 Average property prices by year (2010-2024)]()
# ###### [41] [The Daft.ie House Price Report Q3 2024](https://mcusercontent.com/7dc574a8b74605f879edb49d5/files/fb787d2b-e69f-a3f9-e8ae-666fea2e5205/House_Price_Report_Q3_2024.pdf)
# ###### [42] [pandas.pydata: pandas.DataFrame.resample](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html)
# ###### [43] [Statology: How to Resample Time Series Data in Python (With Examples)](https://www.statology.org/python-resample-time-series/)
# ###### [44] [matplotlib.dates](https://matplotlib.org/stable/api/dates_api.html)
# ###### [45] [Matplotlib.dates.datestr2num() in Python](https://www.geeksforgeeks.org/matplotlib-dates-datestr2num-in-python/?ref=ml_lbp)
# ###### [46] [Statology: Pandas Value Counts Sort Explained](https://www.statology.org/pandas-value_counts-sort/)
# ###### [47] [Restack: How to Sort Results of value_counts()](https://www.restack.io/p/pandas-knowledge-value-counts-sort)
# ###### [48] [Mayo News:Mayo housing prices continue to rise as shortages persists 30SEPT24)]((https://www.mayonews.ie/news/local-news/1617692/mayo-housing-prices-continue-to-rise-as-shortages-persists.html))
# ###### [49] [Seaborn.pydata: seaborn.barplot](https://seaborn.pydata.org/generated/seaborn.barplot.htm)
# ###### [50] [Devsolus:filtering a pandas dataframe string column using the `str.contains` method ](https://devsolus.com/2024/10/29/filtering-a-pandas-dataframe-string-column-using-the-str-contains-method/)
# ###### [51] [pandas.pydata:pandas.Series.str.contains](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.contains.html)
# ###### [52] [w3schools: Python RegEx](https://www.w3schools.com/python/python_regex.asp)
# ###### [53] [GeeksForGeeks: Python Raw Strings](https://www.geeksforgeeks.org/python-raw-strings/)
# ###### [54] [Pytutorial: Python Pandas shape: Quick DataFrame Dimensions](https://pytutorial.com/python-pandas-shape-quick-dataframe-dimensions/?utm_content=cmp-true)
# ###### [55] [PythonGuide: NumPy shape in Python 3 Examples](https://pythonguides.com/python-numpy-shape/)

# %% [markdown]
# ***
# ## End
